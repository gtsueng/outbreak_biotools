# %%
import pandas as pd
from pandas import read_csv
import requests
import json
import math
import time
from datetime import datetime
import copy

# %%
## Remove dictionary keys for empty lists and null values
def cleanNullTerms(d):
    clean = {}   
    for k, v in d.items():
        if v is not None and len(v)>0:
            clean[k] = v   
    return clean

## Fetch the data from biotools
def get_pages(biotoolsapiurl):
    biotoolsapiurl
    payloads = {'format': 'json', 'domain': 'covid-19','page':'i'}
    r = requests.get(biotoolsapiurl, params=payloads, timeout=20).json()
    count = r['count']
    list_num = len(r['list'])
    total_pages = math.ceil(count/list_num)
    return total_pages

## Pull the key for dictionaries with only one key-value pair
def get_dict_key(single_dict):
    keylist = list(single_dict.keys())
    only_key = keylist[0]
    return only_key

## Parse defined terms and format them as a Defined Term object
def parse_defined_terms(definedtermlist):
    try:
        termdf = pd.DataFrame(definedtermlist)
        termdf.rename(columns={'uri':'url','term':'name'},inplace=True)
        termdf['inDefinedTermSet']= 'http://edamontology.org/'
        termdf['@id'] = termdf['url'].str.replace('http://edamontology.org/','')
        termdf['@type'] = 'schema:DefinedTerm'
        termdf['termCode'] = termdf['@id']
        cleandf = termdf[['@type','@id','inDefinedTermSet','termCode','url','name']]
        termjson = cleandf.to_dict(orient="records")
    except:
        termjson = -1
    return termjson

## Parse input and outputs and format as a list of Formal Parameter objects
def parse_parameters(parameterdict):
    datalist = []
    formatlist = []
    for eachparameter in parameterdict:
        content_types = list(eachparameter.keys())
        if 'data' in content_types:
            if isinstance(eachparameter['data'], dict) == True:
                datadictlist = []
                datadictlist.append(eachparameter['data'])
            elif isinstance(eachparameter['data'], list) == True:
                datadictlist = eachparameter['data']
            datavalue = parse_defined_terms(datadictlist)
            if datavalue != -1:
                datalist.extend(datavalue)               
        if 'format' in content_types:
            if isinstance(eachparameter['format'], dict) == True:
                formatdictlist = []
                formatdictlist.append(eachparameter['format'])
            elif isinstance(eachparameter['format'], list) == True:
                formatdictlist = eachparameter['format']
            formatvalue = parse_defined_terms(formatdictlist)
            if formatvalue != -1:
                formatlist.extend(formatvalue)
    if len(datalist) > 0 or len(formatlist) > 0:
        parameterjson = {'@type':'bioschemastypes:FormalParameter',
                         'encodingFormat': datalist,
                         'defaultValue': formatlist}
    else:
        parameterjson = -1
    return parameterjson

## Create an outbreak-compatible json
class cleandoc:
    now = datetime.now()
    basejson = {
      "@type": "outbreak:ComputationalTool",
      "@context": {
        "schema": "http://schema.org/",
        "outbreak": "https://discovery.biothings.io/view/outbreak/",
        "dct": "http://purl.org/dc/terms/"
      },
      "curatedBy": {
        "@type": "outbreak:Organization",
        "name": "ELIXIR bio.tools",
        "url": "https://bio.tools/t?domain=covid-19",
        "identifier": "biotools",
        "affiliation": [{"@type":"outbreak:Organization","name": "ELIXIR"}],
        "curationDate": now.strftime("%Y-%m-%d")
      }
    }
    
    ## Directly add any key/value pair that has minimal transformations
    def add_basic_info(biotooljsonhit): 
        cleanjson = cleandoc.basejson
        cleanjson['name'] = biotooljsonhit['name']
        cleanjson['description'] = biotooljsonhit['description']
        cleanjson['identifier'] = biotooljsonhit['biotoolsID']
        cleanjson['url'] = biotooljsonhit['homepage']
        cleanjson['softwareVersion'] = biotooljsonhit['version']
        cleanjson['applicationCategory'] = biotooljsonhit['toolType']
        cleanjson['license'] = biotooljsonhit['license']
        cleanjson['programmingLanguage'] = biotooljsonhit['language']
        if biotooljsonhit['accessibility'] != None:
            cleanjson['conditionsOfAccess'] = biotooljsonhit['accessibility']
        elif biotooljsonhit['cost'] != None:
            cleanjson['conditionsOfAccess'] = biotooljsonhit['cost']
        try:
            cleanjson['dateModified'] = biotooljsonhit['lastUpdate'].split('T')[0]
        except:
            cleanjson['dateModified'] = biotooljsonhit['lastUpdate']
        try:
            cleanjson['dateCreated'] = biotooljsonhit['additionDate'].split('T')[0]
        except:
            cleanjson['dateCreated'] = biotooljsonhit['additionDate']          
        return cleanjson

    ## Add application subcategory after transforming it
    def add_app_sub_cat(cleanjson,biotooljsonhit): 
        try:
            alltopics = biotooljsonhit['topic']
            topicjson = parse_defined_terms(alltopics)
            if topicjson != -1:
                cleanjson['applicationSubCategory'] = topicjson
        except:
            pass
        return cleanjson
    
    ## Add featuress after transforming them        
    def add_features(cleanjson,biotooljsonhit):
        available_functions = biotooljsonhit['function']
        if len(available_functions) > 0:
            operationlist = []
            inputlist = []
            outputlist = []
        for eachfunction in available_functions:
            ## parse operations
            operations = eachfunction['operation']
            features = parse_defined_terms(operations)
            if features != -1:
                operationlist.extend(features)
            ## parse inputs
            inparameterdict = eachfunction['input']
            inparameters = parse_parameters(inparameterdict)
            if inparameters != -1:
                inputlist.append(inparameters)
            ## parse outputs
            outparameterdict = eachfunction['output']
            outparameters = parse_parameters(outparameterdict)
            if outparameters != -1:
                outputlist.append(outparameters)
                ## Note, additional content available from bio.tools in this section includes 'cmd', and 'notes'
            if len(operationlist)>0:
                cleanjson['featureList'] = operationlist
            if len(inputlist)>0:
                cleanjson['input'] = inputlist
            if len(outputlist)>0:
                cleanjson['output'] = outputlist
        return cleanjson

    ## get the downloadUrl and codeRepository from either link or download
    def add_links(cleanjson,biotooljsonhit): 
        ## pool links
        biotoollinks = []
        if isinstance(biotooljsonhit['link'],list)==True:
            for eachdict in biotooljsonhit['link']:
                biotoollinks.append(eachdict)
        if isinstance(biotooljsonhit['download'],list)==True:
            for eachdict in biotooljsonhit['link']:
                biotoollinks.append(eachdict)
        if isinstance(biotooljsonhit['link'],dict)==True:
            biotoollinks.append(biotooljsonhit['link'])
        if isinstance(biotooljsonhit['download'],dict)==True:
            biotoollinks.append(biotooljsonhit['download'])

        ## Parse links
        if len(biotoollinks) > 0:
            codeRepository = []
            discussionUrl = []
            downloadUrl = []
            for eachitem in biotoollinks:
                if isinstance(eachitem,dict)==True and eachitem['type']!=None:
                    if ('Repository' or 'repository') in eachitem['type']:
                        codeRepository.append(eachitem['url'])
                    if ('Issue' or 'issue') in eachitem['type']:
                        discussionUrl.append(eachitem['url'])
                    if ('file' in eachitem['type']):
                        downloadUrl.append(eachitem['url'])
                    if ('note' in eachitem.keys()) and (eachitem['note']!=None) and ('image' in eachitem['note']):
                        downloadUrl.append(eachitem['url'])
            if len(codeRepository)>0:
                cleanjson['codeRepository'] = list(set(codeRepository))
            if len(discussionUrl)>0:
                cleanjson['discussionUrl'] = list(set(discussionUrl))
            if len(downloadUrl)>0:
                cleanjson['downloadUrl'] = list(set(downloadUrl))
        return cleanjson
    
    ## parse softwarehelp from documentation
    def add_softwarehelp(cleanjson,biotooljsonhit):
        if len(biotooljsonhit['documentation'])>0:
            if isinstance(biotooljsonhit['documentation'],list)==True:
                cleanjson['softwareHelp'] = [x['url'] for x in biotooljsonhit['documentation']]
            if isinstance(biotooljsonhit['documentation'],dict)==True:
                cleanjson['softwareHelp'] = [biotooljsonhit['documentation']]
        return cleanjson

    ## parse authors from credit
    def add_author(cleanjson,biotooljsonhit):
        authorlist = []
        for eachhit in biotooljsonhit['credit']:
            newdict = copy.deepcopy(eachhit)
            if newdict['typeEntity'] == 'outbreak:Person':
                newdict['@type'] = 'outbreak:Person'
            elif newdict['typeEntity'] == None: 
                if newdict['orcidid']!= None:
                    newdict['@type'] = 'outbreak:Person'
                else:
                    newdict['@type'] = 'dct:Agent'
            else:
                newdict['@type'] = 'outbreak:Organization'
            newdict['identifier'] = newdict.pop('orcidid',None)
            newdict['role'] = newdict.pop('typeRole',None)
            newdict.pop('gridid',None)
            newdict.pop('rorid',None)
            newdict.pop('fundrefid',None)
            newdict.pop('note',None)
            newdict.pop('typeEntity',None)
            for key, value in dict(newdict).items():
                if (value is None) or (len(value)==0):
                    del newdict[key]
            authorlist.append(newdict)
        cleanjson['author'] = authorlist
        return cleanjson
    
    ## parse citedBy from 'publication'
    def add_citations(cleanjson,biotooljsonhit):
        citedby = []
        for eachpub in biotooljsonhit['publication']:
            tmppub = copy.deepcopy(eachpub)
            tmppub['@type'] = 'outbreak:Publication'
            try:
                tmppub['name'] = tmppub['metadata']['title']
            except:
                tmppub['name'] = None
            tmppub.pop('type')
            tmppub.pop('version')
            tmppub.pop('note')
            tmppub.pop('metadata')
            for key, value in dict(tmppub).items():
                if (value is None) or (len(value)==0):
                    del tmppub[key]
            citedby.append(tmppub)
        cleanjson['citedBy'] = citedby
        
        return cleanjson

# %%
## Fetch the json docs from the API
def download_jsondocs():
    jsondoclist = []
    biotoolsapiurl = 'https://bio.tools/api/t'
    payloads = {'format': 'json', 'domain': 'covid-19','page':'1'}
    r = requests.get(biotoolsapiurl, params=payloads, timeout=5).json()
    count = r['count']
    list_num = len(r['list'])
    total_pages = math.ceil(count/list_num) 
    i=1
    while i < total_pages+1:
        payloads = {'format': 'json', 'domain': 'covid-19','page':i}
        r = requests.get(biotoolsapiurl, params=payloads, timeout=20).json()
        time.sleep(1)
        jsondoclist.extend(r['list'])
        i=i+1
    return jsondoclist

    
## Transform the json docs
def transform_json(jsondoclist):
    for i in range(len(jsondoclist)):
        biotooljsonhit = jsondoclist[i]
        cleanjson = cleandoc.add_basic_info(biotooljsonhit)
        cleanjson = cleandoc.add_app_sub_cat(cleanjson,biotooljsonhit)
        cleanjson = cleandoc.add_features(cleanjson,biotooljsonhit)
        cleanjson = cleandoc.add_links(cleanjson,biotooljsonhit)
        cleanjson = cleandoc.add_softwarehelp(cleanjson,biotooljsonhit)
        cleanjson = cleandoc.add_author(cleanjson,biotooljsonhit)
        cleanjson = cleandoc.add_citations(cleanjson,biotooljsonhit)    
        yield cleanNullTerms(cleanjson)
        

def load_annotations():
    jsondoclist = download_jsondocs()
    doclist = transform_json(jsondoclist)
    yield from doclist

# %% [markdown]
# ### Check Functions

# %%
biotoolsapiurl = 'https://bio.tools/api/t'
payloads = {'format': 'json', 'domain': 'covid-19','page':'1'}
#payloads = {'format': 'json', 'q': 'COVID-19','page':'1'}
r = requests.get(biotoolsapiurl, params=payloads, timeout=5).json()
count = r['count']
list_num = len(r['list'])
total_pages = math.ceil(count/list_num)
print(list_num)
print(count)
print(total_pages)
# Out:
# 10
# 206
# 21

# %%
i=1
while i < total_pages+1:
    payloads = {'format': 'json', 'domain': 'covid-19','page':i}
    r = requests.get(biotoolsapiurl, params=payloads, timeout=20).json()
    time.sleep(1)
    i=i+1

# %%
print(r['list'][4]['credit'])
biotooljsonhit = r['list'][1]
# Out:
# [{'name': 'Bridget P Bannerman', 'email': 'bpc28@cam.ac.uk', 'url': None, 'orcidid': 'https://orcid.org/0000-0002-5746-8283', 'gridid': None, 'rorid': None, 'fundrefid': None, 'typeEntity': 'Person', 'typeRole': [], 'note': None}, {'name': 'R Andres Floto', 'email': 'arf27@cam.ac.uk', 'url': None, 'orcidid': 'https://orcid.org/0000-0002-2188-5659', 'gridid': None, 'rorid': None, 'fundrefid': None, 'typeEntity': 'Person', 'typeRole': [], 'note': None}, {'name': 'Jorge Júlvez', 'email': None, 'url': None, 'orcidid': 'https://orcid.org/0000-0002-7093-228X', 'gridid': None, 'rorid': None, 'fundrefid': None, 'typeEntity': None, 'typeRole': [], 'note': None}, {'name': 'Alexandru Oarga', 'email': None, 'url': None, 'orcidid': 'https://orcid.org/0000-0002-7271-733X', 'gridid': None, 'rorid': None, 'fundrefid': None, 'typeEntity': None, 'typeRole': [], 'note': None}, {'name': 'Tom L Blundell', 'email': None, 'url': None, 'orcidid': None, 'gridid': None, 'rorid': None, 'fundrefid': None, 'typeEntity': None, 'typeRole': [], 'note': None}, {'name': 'Pablo Moreno', 'email': None, 'url': None, 'orcidid': None, 'gridid': None, 'rorid': None, 'fundrefid': None, 'typeEntity': None, 'typeRole': [], 'note': None}]

# %%
print(biotooljsonhit.keys())

# %%
## parse doi from 'otherID' (if available)
biotooljsonhit['otherID']

# %%
cleanjson = transform_json(r['list'])
for eachjson in cleanjson:
    print(eachjson)
# Out:
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'DisGeNET', 'description': 'DisGeNET is a discovery platform containing one of the largest publicly available collections of genes and variants associated to human diseases. DisGeNET integrates data from expert curated repositories, GWAS catalogues, animal models and the scientific literature. DisGeNET data are homogeneously annotated with controlled vocabularies and community-driven ontologies. Additionally, several original metrics are provided to assist the prioritization of genotype–phenotype relationships.\n\nThe current version of DisGeNET (v7.0) contains 1,134,942 gene-disease associations (GDAs), between 21,671 genes and 30,170 diseases, disorders, traits, and clinical or abnormal human phenotypes, and 369,554 variant-disease associations (VDAs), between 194,515 variants and 14,155 diseases, traits, and phenotypes.', 'identifier': 'disgenet', 'url': 'http://www.disgenet.org/', 'softwareVersion': ['Database version 7.0', 'Platform v1.1.0', 'REST API v1.0.0', 'DisGeNET RDF release 7.0', 'disgenet2r R package Version: 0.0.9', 'DisGeNET Cytoscape App Version 7.0.x'], 'applicationCategory': ['Web application', 'SPARQL endpoint', 'Plug-in', 'Web API', 'Database portal'], 'license': 'CC-BY-NC-SA-4.0', 'conditionsOfAccess': 'Open access (with restrictions)', 'dateModified': '2022-06-21', 'dateCreated': '2016-04-06', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_0602', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0602', 'url': 'http://edamontology.org/topic_0602', 'name': 'Molecular interactions, pathways and networks'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3344', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3344', 'url': 'http://edamontology.org/topic_3344', 'name': 'Biomedical science'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0199', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0199', 'url': 'http://edamontology.org/topic_0199', 'name': 'Genetic variation'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0218', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0218', 'url': 'http://edamontology.org/topic_0218', 'name': 'Natural language processing'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0089', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0089', 'url': 'http://edamontology.org/topic_0089', 'name': 'Ontology and terminology'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0091', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0091', 'url': 'http://edamontology.org/topic_0091', 'name': 'Bioinformatics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3366', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3366', 'url': 'http://edamontology.org/topic_3366', 'name': 'Data integration and warehousing'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3345', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3345', 'url': 'http://edamontology.org/topic_3345', 'name': 'Data identity and mapping'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3342', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3342', 'url': 'http://edamontology.org/topic_3342', 'name': 'Translational medicine'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0634', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0634', 'url': 'http://edamontology.org/topic_0634', 'name': 'Pathology'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0625', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0625', 'url': 'http://edamo ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'V-pipe', 'description': 'Bioinformatics pipeline for the analysis of next-generation sequencing data derived from intra-host viral populations.', 'identifier': 'v-pipe', 'url': 'https://cbg-ethz.github.io/V-pipe/', 'softwareVersion': ['v2.99.2', 'v2.99.1', 'v2.99.0', 'v2.0', 'v1.0'], 'applicationCategory': ['Command-line tool', 'Workflow'], 'license': 'Apache-2.0', 'programmingLanguage': ['Shell', 'Python'], 'conditionsOfAccess': 'Open access', 'dateModified': '2022-03-31', 'dateCreated': '2018-02-02', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_0622', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0622', 'url': 'http://edamontology.org/topic_0622', 'name': 'Genomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3056', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3056', 'url': 'http://edamontology.org/topic_3056', 'name': 'Population genetics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0769', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0769', 'url': 'http://edamontology.org/topic_0769', 'name': 'Workflows'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0781', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0781', 'url': 'http://edamontology.org/topic_0781', 'name': 'Virology'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3168', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3168', 'url': 'http://edamontology.org/topic_3168', 'name': 'Sequencing'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_3219', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3219', 'url': 'http://edamontology.org/operation_3219', 'name': 'Read pre-processing'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0292', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0292', 'url': 'http://edamontology.org/operation_0292', 'name': 'Sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3197', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3197', 'url': 'http://edamontology.org/operation_3197', 'name': 'Genetic variation analysis'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_2975', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_2975', 'url': 'http://edamontology.org/data_2975', 'name': 'Nucleic acid sequence (raw)'}], 'defaultValue': []}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0920', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0920', 'url': 'http://edamontology.org/data_0920', 'name': 'Genotype/phenotype report'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_3016', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_3016', 'url': 'http://edamontology.org/format_3016', 'name': 'VCF'}, {'@type': 'schema:DefinedTerm', '@id': 'format_1929', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_1929', 'url': 'http://edamontology.org/format_1929', 'name': 'FASTA'}]}], 'codeRepository': ['https://github.com/cbg-ethz/V-pipe'], 'softwareHelp': ['https://cbg-ethz.github.io/V-pipe/usage/', 'https://github.com/cbg-ethz/V-pipe/blob/master/README.md', 'https://github.com/cbg-ethz/V-pipe/blob/master/config/README.md', 'https://github.com/cbg-ethz/V-pipe/wiki/benchmark', 'https://github.com/cbg-ethz/V-pipe/wiki/snakemake', 'https://youtu.be/qHEUVJZsgE4', 'https://cbg-ethz.github.io/V- ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'impuSARS', 'description': 'impuSARS allows the imputation of viral whole genome sequences from partially sequenced samples. Additionally, impuSARS provides the lineage associated to the imputed sequence. impuSARS have been validated with a reference of SARS-CoV-2 sequences.', 'identifier': 'impusars', 'url': 'https://github.com/babelomics/impuSARS', 'softwareVersion': ['v1.0', 'v2.0', 'v3.0', 'v3.1'], 'applicationCategory': ['Command-line tool'], 'license': 'MIT', 'programmingLanguage': ['Python', 'Bash'], 'conditionsOfAccess': 'Open access', 'dateModified': '2022-03-11', 'dateCreated': '2021-09-10', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_3307', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3307', 'url': 'http://edamontology.org/topic_3307', 'name': 'Computational biology'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0080', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0080', 'url': 'http://edamontology.org/topic_0080', 'name': 'Sequence analysis'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0091', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0091', 'url': 'http://edamontology.org/topic_0091', 'name': 'Bioinformatics'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_3219', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3219', 'url': 'http://edamontology.org/operation_3219', 'name': 'Read pre-processing'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0292', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0292', 'url': 'http://edamontology.org/operation_0292', 'name': 'Sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3197', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3197', 'url': 'http://edamontology.org/operation_3197', 'name': 'Genetic variation analysis'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_2975', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_2975', 'url': 'http://edamontology.org/data_2975', 'name': 'Nucleic acid sequence (raw)'}], 'defaultValue': []}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0920', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0920', 'url': 'http://edamontology.org/data_0920', 'name': 'Genotype/phenotype report'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_3016', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_3016', 'url': 'http://edamontology.org/format_3016', 'name': 'VCF'}, {'@type': 'schema:DefinedTerm', '@id': 'format_1929', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_1929', 'url': 'http://edamontology.org/format_1929', 'name': 'FASTA'}]}], 'codeRepository': ['https://github.com/cbg-ethz/V-pipe'], 'softwareHelp': ['https://cbg-ethz.github.io/V-pipe/usage/', 'https://github.com/cbg-ethz/V-pipe/blob/master/README.md', 'https://github.com/cbg-ethz/V-pipe/blob/master/config/README.md', 'https://github.com/cbg-ethz/V-pipe/wiki/benchmark', 'https://github.com/cbg-ethz/V-pipe/wiki/snakemake', 'https://youtu.be/qHEUVJZsgE4', 'https://cbg-ethz.github.io/V-pipe/tutorial/sars-cov2/', 'https://youtu.be/pIby1UooK94']}
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'nf-core-viralrecon', 'description': 'nfcore/viralrecon is a bioinformatics analysis pipeline used to perform assembly and intra-host/low-frequency variant calling for viral samples. The pipeline supports short-read Illumina sequencing data from both shotgun (e.g. sequencing directly from clinical samples) and enrichment-based library preparation methods (e.g. amplicon-based: ARTIC SARS-CoV-2 enrichment protocol; or probe-capture-based).', 'identifier': 'nf-core-viralrecon', 'url': 'https://nf-co.re/viralrecon', 'softwareVersion': ['1.0.0', '1.1.0', '2.0', '2.1', '2.2', '2.3', '2.3.1', '2.4', '2.4.1'], 'applicationCategory': ['Command-line tool', 'Workflow'], 'license': 'MIT', 'programmingLanguage': ['Groovy'], 'conditionsOfAccess': 'Open access', 'dateModified': '2022-03-11', 'dateCreated': '2021-01-13', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_0622', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0622', 'url': 'http://edamontology.org/topic_0622', 'name': 'Genomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0781', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0781', 'url': 'http://edamontology.org/topic_0781', 'name': 'Virology'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3796', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3796', 'url': 'http://edamontology.org/topic_3796', 'name': 'Population genomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0199', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0199', 'url': 'http://edamontology.org/topic_0199', 'name': 'Genetic variation'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3168', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3168', 'url': 'http://edamontology.org/topic_3168', 'name': 'Sequencing'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0102', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0102', 'url': 'http://edamontology.org/topic_0102', 'name': 'Mapping'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0769', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0769', 'url': 'http://edamontology.org/topic_0769', 'name': 'Workflows'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_0292', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0292', 'url': 'http://edamontology.org/operation_0292', 'name': 'Sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3197', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3197', 'url': 'http://edamontology.org/operation_3197', 'name': 'Genetic variation analysis'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0525', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0525', 'url': 'http://edamontology.org/operation_0525', 'name': 'Genome assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0346', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0346', 'url': 'http://edamontology.org/operation_0346', 'name': 'Sequence similarity search'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3227', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3227', 'url': 'http://edamontology.org/operation_3227', 'name': 'Variant calling'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3731', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3731', 'url': 'http://edamontology.org/operation_3731', 'name': 'Sample comparison'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'enco ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'ifindCPcli', 'description': 'findCPcli is a command line python-tool for the computation of chokepoint reactions in genome-scale metabolic models. The main purpose of the tool is to compute chokepoints by taking into account both the topology and the dynamic information of the network. In addition to the computation of chokepoints, findCPcli can compute and remove dead-end metabolites, find essential reactions and update the flux bounds of the reactions according to the results of Flux Variability Analysis.\n\nfindCPcli takes as input an SBML files of genome-scale models, and provides as output a spreadsheet file with the results of the chokepoint computation.', 'identifier': 'ifindcpcli', 'url': 'https://github.com/findCP/findCPcli', 'applicationCategory': ['Command-line tool'], 'license': 'GPL-3.0', 'programmingLanguage': ['Python', 'Shell'], 'conditionsOfAccess': 'Open access', 'dateModified': '2022-01-18', 'dateCreated': '2022-01-18', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_0154', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0154', 'url': 'http://edamontology.org/topic_0154', 'name': 'Small molecules'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3407', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3407', 'url': 'http://edamontology.org/topic_3407', 'name': 'Endocrinology and metabolism'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3172', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3172', 'url': 'http://edamontology.org/topic_3172', 'name': 'Metabolomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0602', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0602', 'url': 'http://edamontology.org/topic_0602', 'name': 'Molecular interactions, pathways and networks'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0821', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0821', 'url': 'http://edamontology.org/topic_0821', 'name': 'Enzymes'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_3660', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3660', 'url': 'http://edamontology.org/operation_3660', 'name': 'Metabolic network modelling'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_4009', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_4009', 'url': 'http://edamontology.org/operation_4009', 'name': 'Small molecule design'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3929', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3929', 'url': 'http://edamontology.org/operation_3929', 'name': 'Metabolic pathway prediction'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0950', 'url': 'http://edamontology.org/data_0950', 'name': 'Mathematical model'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2585', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2585', 'url': 'http://edamontology.org/format_2585', 'name': 'SBML'}]}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_1383', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_1383', 'url': 'http://edamontology.org/data_1383', 'name': 'Nucleic acid sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'data_0925', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_092 ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'Llamanade', 'description': 'An open-source computational pipeline for robust nanobody humanization.', 'identifier': 'llamanade', 'url': 'https://github.com/sangzhe/Llamanade', 'applicationCategory': ['Script'], 'license': 'Not licensed', 'programmingLanguage': ['Python', 'Shell'], 'conditionsOfAccess': 'Open access', 'dateModified': '2022-01-14', 'dateCreated': '2022-01-14', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_3379', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3379', 'url': 'http://edamontology.org/topic_3379', 'name': 'Preclinical and clinical studies'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_2830', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_2830', 'url': 'http://edamontology.org/topic_2830', 'name': 'Immunoproteins and antigens'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3168', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3168', 'url': 'http://edamontology.org/topic_3168', 'name': 'Sequencing'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0769', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0769', 'url': 'http://edamontology.org/topic_0769', 'name': 'Workflows'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3398', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3398', 'url': 'http://edamontology.org/topic_3398', 'name': 'Bioengineering'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_0480', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0480', 'url': 'http://edamontology.org/operation_0480', 'name': 'Side chain modelling'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_2950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_2950', 'url': 'http://edamontology.org/operation_2950', 'name': 'Residue distance calculation'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0337', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0337', 'url': 'http://edamontology.org/operation_0337', 'name': 'Visualisation'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0950', 'url': 'http://edamontology.org/data_0950', 'name': 'Mathematical model'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2585', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2585', 'url': 'http://edamontology.org/format_2585', 'name': 'SBML'}]}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_1383', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_1383', 'url': 'http://edamontology.org/data_1383', 'name': 'Nucleic acid sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'data_0925', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0925', 'url': 'http://edamontology.org/data_0925', 'name': 'Sequence assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3498', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3498', 'url': 'http://edamontology.org/data_3498', 'name': 'Sequence variations'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3914', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3914', 'url': 'http://edamontology.org/data_3914', 'name': 'Quality control report'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2572', 'inDefinedTermSet': 'http://edamontology.org/', 't ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'CovidPhy', 'description': 'Web interface that can process SARS-CoV-2 genome sequences in plain fasta text format or provided through identity codes from the Global Initiative on Sharing Avian Influenza Data (GISAID) or GenBank.', 'identifier': 'covidphy', 'url': 'http://covidphy.eu', 'applicationCategory': ['Web application'], 'programmingLanguage': ['JavaScript'], 'conditionsOfAccess': 'Open access', 'dateModified': '2021-12-31', 'dateCreated': '2021-12-31', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_0084', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0084', 'url': 'http://edamontology.org/topic_0084', 'name': 'Phylogeny'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0099', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0099', 'url': 'http://edamontology.org/topic_0099', 'name': 'RNA'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0080', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0080', 'url': 'http://edamontology.org/topic_0080', 'name': 'Sequence analysis'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0199', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0199', 'url': 'http://edamontology.org/topic_0199', 'name': 'Genetic variation'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_3436', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3436', 'url': 'http://edamontology.org/operation_3436', 'name': 'Aggregation'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_2421', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_2421', 'url': 'http://edamontology.org/operation_2421', 'name': 'Database search'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0548', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0548', 'url': 'http://edamontology.org/operation_0548', 'name': 'Phylogenetic inference (quartet methods)'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0950', 'url': 'http://edamontology.org/data_0950', 'name': 'Mathematical model'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2585', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2585', 'url': 'http://edamontology.org/format_2585', 'name': 'SBML'}]}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_1383', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_1383', 'url': 'http://edamontology.org/data_1383', 'name': 'Nucleic acid sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'data_0925', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0925', 'url': 'http://edamontology.org/data_0925', 'name': 'Sequence assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3498', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3498', 'url': 'http://edamontology.org/data_3498', 'name': 'Sequence variations'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3914', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3914', 'url': 'http://edamontology.org/data_3914', 'name': 'Quality control report'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2572', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2572', 'url': 'http://edamontology.org/format_2572', 'name': 'BAM'}, {'@type': 'schema:DefinedTerm', '@id': 'format_3327', ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'COVID-ONE-humoral immune', 'description': 'The One-stop Database for COVID-19-specific Antibody Responses and Clinical Parameters.', 'identifier': 'pub2tools2021__covid-one-humoral-immune', 'url': 'http://www.COVID-ONE.cn', 'applicationCategory': ['Database portal'], 'conditionsOfAccess': 'Open access', 'dateModified': '2021-12-31', 'dateCreated': '2021-12-31', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_3518', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3518', 'url': 'http://edamontology.org/topic_3518', 'name': 'Microarray experiment'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0121', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0121', 'url': 'http://edamontology.org/topic_0121', 'name': 'Proteomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0154', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0154', 'url': 'http://edamontology.org/topic_0154', 'name': 'Small molecules'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0203', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0203', 'url': 'http://edamontology.org/topic_0203', 'name': 'Gene expression'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0080', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0080', 'url': 'http://edamontology.org/topic_0080', 'name': 'Sequence analysis'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_0252', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0252', 'url': 'http://edamontology.org/operation_0252', 'name': 'Peptide immunogenicity prediction'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0314', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0314', 'url': 'http://edamontology.org/operation_0314', 'name': 'Gene expression profiling'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3431', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3431', 'url': 'http://edamontology.org/operation_3431', 'name': 'Deposition'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0950', 'url': 'http://edamontology.org/data_0950', 'name': 'Mathematical model'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2585', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2585', 'url': 'http://edamontology.org/format_2585', 'name': 'SBML'}]}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_1383', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_1383', 'url': 'http://edamontology.org/data_1383', 'name': 'Nucleic acid sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'data_0925', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0925', 'url': 'http://edamontology.org/data_0925', 'name': 'Sequence assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3498', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3498', 'url': 'http://edamontology.org/data_3498', 'name': 'Sequence variations'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3914', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3914', 'url': 'http://edamontology.org/data_3914', 'name': 'Quality control report'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2572', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_257 ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'coronaSPAdes', 'description': 'CoronaSPAdes – a novel assembler for RNA viral species recovery in general and coronaviruses in particular.', 'identifier': 'coronaspades', 'url': 'http://cab.spbu.ru/software/spades', 'applicationCategory': ['Library'], 'programmingLanguage': ['Python'], 'conditionsOfAccess': 'Open access', 'dateModified': '2021-12-19', 'dateCreated': '2021-12-19', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_3308', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3308', 'url': 'http://edamontology.org/topic_3308', 'name': 'Transcriptomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0196', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0196', 'url': 'http://edamontology.org/topic_0196', 'name': 'Sequence assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3174', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3174', 'url': 'http://edamontology.org/topic_3174', 'name': 'Metagenomics'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_0160', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0160', 'url': 'http://edamontology.org/topic_0160', 'name': 'Sequence sites, features and motifs'}, {'@type': 'schema:DefinedTerm', '@id': 'topic_3297', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_3297', 'url': 'http://edamontology.org/topic_3297', 'name': 'Biotechnology'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_0524', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0524', 'url': 'http://edamontology.org/operation_0524', 'name': 'De-novo assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3258', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3258', 'url': 'http://edamontology.org/operation_3258', 'name': 'Transcriptome assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0525', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0525', 'url': 'http://edamontology.org/operation_0525', 'name': 'Genome assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3216', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3216', 'url': 'http://edamontology.org/operation_3216', 'name': 'Scaffolding'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0950', 'url': 'http://edamontology.org/data_0950', 'name': 'Mathematical model'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2585', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2585', 'url': 'http://edamontology.org/format_2585', 'name': 'SBML'}]}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_1383', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_1383', 'url': 'http://edamontology.org/data_1383', 'name': 'Nucleic acid sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'data_0925', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0925', 'url': 'http://edamontology.org/data_0925', 'name': 'Sequence assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3498', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3498', 'url': 'http://edamontology.org/data_3498', 'name': 'Sequence variations'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3914', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_391 ...
# {'@type': 'outbreak:ComputationalTool', '@context': {'schema': 'http://schema.org/', 'outbreak': 'https://discovery.biothings.io/view/outbreak/'}, 'curatedBy': {'@type': 'outbreak:Organization', 'name': 'ELIXIR bio.tools', 'url': 'https://bio.tools/t?domain=covid-19', 'identifier': 'biotools', 'affiliation': [{'@type': 'outbreak:Organization', 'name': 'ELIXIR'}], 'curationDate': '2022-08-04'}, 'name': 'PHA4GE SARS-CoV-2 Contextual Data Specification', 'description': 'Software package as collection template and associated materials for SARS-CoV-2 metadata.\nContains metadata collection template based on data standard designed to harmonize genomic surveillance contextual data (sample metadata, epidemiological/clinical/laboratory data, methods information) across datasets, laboratories and databases during pandemic, and beyond. Template contains standardized fields, terms and formats for structuring information, and is accompanied by field level reference guide which provides definitions, guidance and examples for populating fields. Fields have been prioritized using colour coding system as required (yellow), recommended (purple), and optional (white). Users can use as much or as little of specification as they wish, according to their needs, and need not share information unless permitted to do so. SOP and protocols for submitting to public repositories are also included.', 'identifier': 'pha4ge_sars-cov-2_contextual_data_specification', 'url': 'https://github.com/pha4ge/SARS-CoV-2-Contextual-Data-Specification', 'applicationCategory': ['Desktop application'], 'license': 'CC-BY-4.0', 'conditionsOfAccess': 'Open access', 'dateModified': '2021-12-08', 'dateCreated': '2021-12-08', 'applicationSubCategory': [{'@type': 'schema:DefinedTerm', '@id': 'topic_0089', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'topic_0089', 'url': 'http://edamontology.org/topic_0089', 'name': 'Ontology and terminology'}], 'featuresList': [{'@type': 'schema:DefinedTerm', '@id': 'operation_2409', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_2409', 'url': 'http://edamontology.org/operation_2409', 'name': 'Data handling'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_0335', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_0335', 'url': 'http://edamontology.org/operation_0335', 'name': 'Formatting'}, {'@type': 'schema:DefinedTerm', '@id': 'operation_3096', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'operation_3096', 'url': 'http://edamontology.org/operation_3096', 'name': 'Editing'}], 'input': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_0950', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0950', 'url': 'http://edamontology.org/data_0950', 'name': 'Mathematical model'}], 'defaultValue': [{'@type': 'schema:DefinedTerm', '@id': 'format_2585', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'format_2585', 'url': 'http://edamontology.org/format_2585', 'name': 'SBML'}]}], 'output': [{'@type': 'bioschemastypes:FormalParameter', 'encodingFormat': [{'@type': 'schema:DefinedTerm', '@id': 'data_1383', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_1383', 'url': 'http://edamontology.org/data_1383', 'name': 'Nucleic acid sequence alignment'}, {'@type': 'schema:DefinedTerm', '@id': 'data_0925', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_0925', 'url': 'http://edamontology.org/data_0925', 'name': 'Sequence assembly'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3498', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3498', 'url': 'http://edamontology.org/data_3498', 'name': 'Sequence variations'}, {'@type': 'schema:DefinedTerm', '@id': 'data_3914', 'inDefinedTermSet': 'http://edamontology.org/', 'termCode': 'data_3914', 'url': 'http://edamontology.org/data_3914', 'name': 'Quality control report'}], 'defaultValue': [{'@type': 'schema:Defi ...

# %% [markdown]
# ### Run time check

# %%
# %%time

jsondoclist = download_jsondocs()
print(len(jsondoclist))
# Out:
# 206
# Wall time: 38.8 s

# %%
# %%time

doclist = transform_json(jsondoclist)

i=0
for doc in doclist:
    i=i+1
print(i)
# Out:
# 206
# Wall time: 1.77 s

# %% [markdown]
# ### Integrated, and no longer needed

# %%
def add_version(cleanjson, biotooljsonhit):
    try:
        cleanjson['softwareVersion'] = biotooljsonhit['version']
    except:
        pass
    return(cleanjson) 
   
    
def add_application_cat(cleanjson, biotooljsonhit):
    try:
        cleanjson['applicationCategory'] = biotooljsonhit['toolType']
    except:
        pass
    return(cleanjson)

# %%
cleanjson = cleandoc.add_basic_info(biotooljsonhit)
#print(cleanjson)
cleanjson = cleandoc.add_app_sub_cat(cleanjson,biotooljsonhit)
#print(cleanjson)
cleanjson = cleandoc.add_features(cleanjson,biotooljsonhit)
#print(cleanjson)
cleanjson = cleandoc.add_links(cleanjson,biotooljsonhit)
#print(cleanjson)
cleanjson = cleandoc.add_softwarehelp(cleanjson,biotooljsonhit)
#print(cleanjson)
cleanjson = cleandoc.add_author(cleanjson,biotooljsonhit)
#print(cleanjson)
cleanjson = cleandoc.add_citations(cleanjson,biotooljsonhit)
print(cleanjson)
